# %% [markdown]
# <a href="https://colab.research.google.com/github/Akazelll/RiceLeafDisease/blob/main/final_efficientnetB0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# IMPORTANT: RUN THIS CELL IN ORDER TO IMPORT YOUR KAGGLE DATA SOURCES,
# THEN FEEL FREE TO DELETE THIS CELL.
# NOTE: THIS NOTEBOOK ENVIRONMENT DIFFERS FROM KAGGLE'S PYTHON
# ENVIRONMENT SO THERE MAY BE MISSING LIBRARIES USED BY YOUR
# NOTEBOOK.
import kagglehub
loki4514_rice_leaf_diseases_detection_path = kagglehub.dataset_download('loki4514/rice-leaf-diseases-detection')

print('Data source import complete.')
# Out:
# Using Colab cache for faster access to the 'rice-leaf-diseases-detection' dataset.
# Data source import complete.

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All"
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# Output streaming akan dipotong hingga 5000 baris terakhir.
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_511.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_2482.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_9857.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_2720.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_41.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_8477.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_3440.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_8279.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_50.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_9890.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_8108.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_107.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_8093.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_8651.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_1036.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_6260.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_9395.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_6700.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_4109.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_2050.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_3576.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/IMG_20231014_173815.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_1877.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_950.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_9808.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_1387.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_7581.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_5318.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_7839.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/Narrow_brown_leaf_spot (47).jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_4423.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/Narrow_brown_leaf_spot (41).jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_6878.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_5478.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/Narrow_brown_leaf_spot (35).jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_9537.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_8517.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_6220.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_4608.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/IMG_20231014_172737.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_7522.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_9993.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/Narrow_brown_leaf_spot (54).jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_8458.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_3320.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_366.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_9707.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_3335.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_754.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_3688.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_8399.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_3916.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_1996.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_3240.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/IMG_20231014_170806.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_7519.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_65.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_6180.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_7928.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/Narrow_brown_leaf_spot (49).jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_3017.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_7668.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_1672.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_3156.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_3586.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_7837.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/Narrow_brown_leaf_spot (88).jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_8530.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_6412.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_9596.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_7621.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_2669.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_7155.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_8583.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_926.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_9393.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_6816.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_6303.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_7914.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_4422.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_6482.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_3589.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_5543.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_150.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_7890.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_7132.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_9274.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_288.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_1138.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_2066.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_6179.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_8751.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_7116.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_2908.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/IMG_20231018_143445.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_5550.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/IMG_20231018_143439.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_1078.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_4700.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_3794.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_8809.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_5358.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_5088.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_3796.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_8985.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_496.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_5871.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_943.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_2896.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/IMG_20231014_172738.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_526.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_3484.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_6091.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_1355.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_7153.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/IMG_20231014_172140.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/IMG_20231014_173039.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_7908.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_7720.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_1246.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_2286.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_2970.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_2273.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_3989.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/Narrow_brown_leaf_spot (1).jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_3210.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_830.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_3008.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_1300.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_5844.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/Narrow_brown_leaf_spot (42).jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_8595.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_4764.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_7861.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_1317.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/IMG_20231018_143431_1.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_7830.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_661.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_8105.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_3825.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_7357.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_2364.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/IMG_20231014_170817.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_7409.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_1584.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/IMG_20231014_172121.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_2678.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_2442.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_7137.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/Narrow_brown_leaf_spot (6).jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_4194.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/Narrow_brown_leaf_spot (75).jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_6437.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/Narrow_brown_leaf_spot (16).jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/Narrow_brown_leaf_spot (38).jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_1366.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_4122.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_5625.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_725.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_2558.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_4393.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_8554.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_3161.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_5323.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_8044.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_757.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_3469.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_6630.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/IMG_20231018_143431.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_5180.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_741.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_2564.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/Narrow_brown_leaf_spot (11).jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/Narrow_brown_leaf_spot (20).jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/Narrow_brown_leaf_spot (19).jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_1249.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/Narrow_brown_leaf_spot (83).jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_9637.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_9232.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_4296.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/IMG_20231014_172113.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_6863.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_9234.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_7331.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_9349.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_9459.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_3313.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/Narrow_brown_leaf_spot (80).jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/Narrow_brown_leaf_spot (85).jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/Narrow_brown_leaf_spot (40).jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_6756.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_769.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_9373.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_7339.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_1975.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_2516.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_64.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_3228.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/Narrow_brown_leaf_spot (50).jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_4674.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_5204.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_1289.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_1520.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_7050.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_2164.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_8772.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_5739.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_8634.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_3573.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_8810.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_5260.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_5361.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/Narrow_brown_leaf_spot (7).jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_9905.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_5175.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_5866.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_6313.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_3306.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_3777.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_9982.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_1020.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_6382.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_7215.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_8731.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_8330.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_4120.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/IMG_20231018_143449.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/IMG_20231018_143411.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_8244.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/Narrow_brown_leaf_spot (30).jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_7441.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_3494.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_956.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_8797.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/Narrow_brown_leaf_spot (64).jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_3638.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_6693.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/IMG_20231014_173100.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_1800.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/Narrow_brown_leaf_spot (24).jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_6239.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/IMG_20231014_170800.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_2605.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_3052.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_8527.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_786.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_7921.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/Narrow_brown_leaf_spot (63).jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/Narrow_brown_leaf_spot (48).jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_2821.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_3511.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/IMG_20231014_173058.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_7642.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_7260.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/Narrow_brown_leaf_spot (3).jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/IMG_20231006_163942.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_4333.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_2233.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_7277.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_4041.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_870.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_4540.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_1622.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_6989.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_4910.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_1615.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_3802.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/IMG_20231018_143836.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_5933.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_4494.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_7584.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_9300.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_6978.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_3328.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/IMG_20231014_172730.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_532.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_5512.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_6311.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_8126.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_2119.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/Narrow_brown_leaf_spot (58).jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_8384.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_9273.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_7771.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_2866.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_7679.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_5837.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_3151.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_5806.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_8401.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_4848.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/Narrow_brown_leaf_spot (14).jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_181.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_6797.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_2886.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/IMG_20231014_173030.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_6106.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_1867.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/Narrow_brown_leaf_spot (23).jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/Narrow_brown_leaf_spot (57).jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_9954.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_3997.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_4372.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_3939.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_5201.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_3369.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/Narrow_brown_leaf_spot (2).jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_3731.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_4773.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_4105.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_3035.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_8979.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_6256.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_2965.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_7616.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_625.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_2904.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_9780.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_8684.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/IMG_20231002_171633.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_6877.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_4119.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_3799.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_4474.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_9285.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_1196.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_4214.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_7482.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_4760.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/Narrow_brown_leaf_spot (84).jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_6998.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_9103.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/IMG_20231014_173036.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_4537.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/Narrow_brown_leaf_spot (37).jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_1083.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_7191.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_5297.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/IMG_20231018_143414.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/IMG_20231018_143442.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_7168.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/Narrow_brown_leaf_spot (22).jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_7624.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_6555.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/Narrow_brown_leaf_spot (9).jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_18.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/IMG_20231014_172412.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_8095.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_8871.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_1982.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_4318.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_2082.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/IMG_20231014_172413.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_1128.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_1771.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_4303.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_9365.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/IMG_20231018_143441.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_1189.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_2347.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_4288.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_357.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/IMG_20231014_172721.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/IMG_20231018_144021.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_4627.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_2150.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_615.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_8916.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_140.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_6713.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_5701.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/IMG_20231014_173101.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_789.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_7751.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_2930.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_5423.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_8147.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_8166.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_2497.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_4014.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/Narrow_brown_leaf_spot (28).jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_8800.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_740.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_6351.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/Narrow_brown_leaf_spot (27).jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_7070.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_4070.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/Narrow_brown_leaf_spot (29).jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_3891.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_3608.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_6965.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_3300.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/IMG_20231018_143428.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_1734.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_6716.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_1530.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_2660.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_1044.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_1671.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_5711.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/IMG_20231014_173056.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/IMG_20231014_170823.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_1593.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_5060.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_4624.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_9250.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Narrow Brown Leaf Spot/aug_0_6346.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Leaf Blast/IMG_20231006_172820.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Leaf Blast/aug_0_6889.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Leaf Blast/aug_0_9464.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Leaf Blast/aug_0_1764.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Leaf Blast/aug_0_5635.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Leaf Blast/IMG_20231018_144004.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Leaf Blast/aug_0_3054.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Leaf Blast/aug_0_3620.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Leaf Blast/aug_0_9584.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Leaf Blast/aug_0_7164.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Leaf Blast/IMG_20231014_172034_1.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Leaf Blast/aug_0_7293.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Leaf Blast/aug_0_4107.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Leaf Blast/aug_0_8300.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Leaf Blast/aug_0_2554.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Leaf Blast/IMG_20231014_171556.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Leaf Blast/aug_0_9935.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Leaf Blast/aug_0_5821.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Leaf Blast/aug_0_7524.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Leaf Blast/IMG_20231018_143730.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Leaf Blast/aug_0_5719.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Leaf Blast/aug_0_7474.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Leaf Blast/aug_0_7107.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Leaf Blast/20231006_170252.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Leaf Blast/aug_0_1852.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Leaf Blast/aug_0_9811.jpg
# ...
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Brown Spot/Brown_spot (58).jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Brown Spot/aug_0_5450.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Brown Spot/aug_0_318.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Brown Spot/Brown_spot (179).jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Brown Spot/Brown_spot (145).jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Brown Spot/aug_0_6122.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Brown Spot/aug_0_6236.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Brown Spot/aug_0_1867.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Brown Spot/aug_0_2641.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Brown Spot/aug_0_6418.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Brown Spot/aug_0_9013.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Brown Spot/aug_0_4352.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Brown Spot/aug_0_5071.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Brown Spot/aug_0_4865.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Brown Spot/aug_0_6050.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Brown Spot/aug_0_6631.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Brown Spot/aug_0_5009.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Brown Spot/Brown_spot (121).jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Brown Spot/IMG_20231018_143713.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Brown Spot/Brown_spot (95).jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Brown Spot/Brown_spot (27).jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Brown Spot/aug_0_9151.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Brown Spot/aug_0_81.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Brown Spot/aug_0_1601.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Brown Spot/aug_0_5577.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Brown Spot/aug_0_3731.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Brown Spot/aug_0_6975.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Brown Spot/aug_0_7031.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Brown Spot/aug_0_6632.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Brown Spot/aug_0_979.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Brown Spot/Brown_spot (139).jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Brown Spot/aug_0_44.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Brown Spot/aug_0_5151.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Brown Spot/aug_0_5303.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Brown Spot/aug_0_2261.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Brown Spot/aug_0_7616.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Brown Spot/aug_0_625.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Brown Spot/aug_0_449.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Brown Spot/Brown_spot (18).jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Brown Spot/aug_0_2438.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Brown Spot/aug_0_3961.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Brown Spot/aug_0_7244.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Brown Spot/Brown_spot (135).jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Brown Spot/Brown_spot (45).jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Brown Spot/aug_0_2745.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Brown Spot/aug_0_4312.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Brown Spot/aug_0_9523.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Brown Spot/aug_0_8738.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Brown Spot/aug_0_5369.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Brown Spot/Brown_spot (81).jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Brown Spot/aug_0_7721.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Brown Spot/aug_0_6908.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Brown Spot/IMG_20231014_171720.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Brown Spot/20231006_165801.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Brown Spot/aug_0_6163.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Brown Spot/Brown_spot (22).jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Brown Spot/aug_0_3214.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Brown Spot/aug_0_8461.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Brown Spot/aug_0_2040.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Brown Spot/aug_0_6671.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Brown Spot/aug_0_6998.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Brown Spot/aug_0_5007.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Brown Spot/aug_0_4271.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Brown Spot/aug_0_6827.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Brown Spot/aug_0_3872.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Brown Spot/Brown_spot (187).jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Brown Spot/aug_0_6478.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Brown Spot/Brown_spot (220).jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Brown Spot/aug_0_1119.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Brown Spot/aug_0_4662.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Brown Spot/aug_0_2494.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Brown Spot/aug_0_3136.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Brown Spot/aug_0_7731.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Brown Spot/aug_0_5671.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Brown Spot/aug_0_1643.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Brown Spot/aug_0_2220.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Brown Spot/aug_0_1780.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Brown Spot/Brown_spot (199).jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Brown Spot/aug_0_6489.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Brown Spot/Brown_spot (85).jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Brown Spot/aug_0_18.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Brown Spot/aug_0_99.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Brown Spot/aug_0_4629.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Brown Spot/Brown_spot (137).jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Brown Spot/aug_0_1773.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Brown Spot/aug_0_8369.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Brown Spot/aug_0_4140.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Brown Spot/aug_0_7358.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Brown Spot/aug_0_1982.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Brown Spot/aug_0_2271.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Brown Spot/IMG_20231018_142956.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Brown Spot/aug_0_7574.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Brown Spot/aug_0_5112.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Brown Spot/aug_0_5061.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Brown Spot/Brown_spot (57).jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Brown Spot/aug_0_6190.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Brown Spot/aug_0_7432.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Brown Spot/aug_0_7271.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Brown Spot/aug_0_7925.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Brown Spot/aug_0_3044.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Brown Spot/Brown_spot (148).jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Brown Spot/aug_0_6425.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Brown Spot/aug_0_1189.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Brown Spot/aug_0_9838.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Brown Spot/aug_0_7957.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Brown Spot/aug_0_3763.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Brown Spot/aug_0_4814.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Brown Spot/aug_0_8742.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Brown Spot/aug_0_7632.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Brown Spot/aug_0_3301.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Brown Spot/Brown_spot (87).jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Brown Spot/aug_0_3467.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Brown Spot/aug_0_701.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Brown Spot/aug_0_5237.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Brown Spot/aug_0_989.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Brown Spot/aug_0_8094.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Brown Spot/aug_0_5503.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Brown Spot/aug_0_1057.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Brown Spot/aug_0_5064.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Brown Spot/aug_0_1751.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Brown Spot/Brown_spot (113).jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Brown Spot/aug_0_6713.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Brown Spot/aug_0_4127.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Brown Spot/Brown_spot (68).jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Brown Spot/aug_0_2610.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Brown Spot/aug_0_7797.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Brown Spot/aug_0_789.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Brown Spot/aug_0_4401.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Brown Spot/aug_0_5423.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Brown Spot/Brown_spot (49).jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Brown Spot/aug_0_9861.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Brown Spot/aug_0_3253.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Brown Spot/aug_0_7742.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Brown Spot/aug_0_1761.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Brown Spot/aug_0_5153.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Brown Spot/aug_0_7317.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Brown Spot/aug_0_6131.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Brown Spot/Brown_spot (130).jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Brown Spot/aug_0_9398.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Brown Spot/aug_0_6208.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Brown Spot/aug_0_4912.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Brown Spot/aug_0_8486.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Brown Spot/aug_0_3931.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Brown Spot/aug_0_9062.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Brown Spot/aug_0_5301.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Brown Spot/Brown_spot (5).jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Brown Spot/aug_0_7310.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Brown Spot/aug_0_280.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Brown Spot/Brown_spot (34).jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Brown Spot/aug_0_6780.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Brown Spot/Brown_spot (163).jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Brown Spot/aug_0_579.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Brown Spot/aug_0_4470.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Brown Spot/IMG_20231014_172423.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Brown Spot/aug_0_1671.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Brown Spot/aug_0_1450.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Brown Spot/aug_0_5520.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Brown Spot/aug_0_1593.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Brown Spot/aug_0_1279.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Brown Spot/IMG_20231014_171715.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Brown Spot/aug_0_5551.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Brown Spot/aug_0_6346.jpg
# /kaggle/input/rice-leaf-diseases-detection/Rice_Leaf_AUG/Rice_Leaf_AUG/Brown Spot/aug_0_8240.jpg

# %%
# ==============================================================================
# 1. DATA COLLECTING
# ==============================================================================
import os
import random
import numpy as np
import tensorflow as tf

print("\n===== 1. DATA COLLECTING ====")

SEED = 42
random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)

# Corrected SOURCE_DIR to use the path from kagglehub.dataset_download
# The variable 'loki4514_rice_leaf_diseases_detection_path' from the first cell holds the base path.
SOURCE_DIR = os.path.join(loki4514_rice_leaf_diseases_detection_path, 'Rice_Leaf_AUG', 'Rice_Leaf_AUG')

total_images = 0
class_names = []

for cls in sorted(os.listdir(SOURCE_DIR)):
    cls_path = os.path.join(SOURCE_DIR, cls)
    if os.path.isdir(cls_path):
        count = len(os.listdir(cls_path))
        class_names.append(cls)
        total_images += count
        print(f"Class '{cls}': {count} images")

print(f"\nTotal images collected : {total_images}")
print(f"Total classes         : {len(class_names)}")

# %%
# ==============================================================================
# (VISUAL SAMPLE)
# ==============================================================================
import os
import matplotlib.pyplot as plt
from PIL import Image

print("\n===== Sampel Visual Gambar Asli =====")

sample_class = class_names[0]
sample_img = os.listdir(os.path.join(SOURCE_DIR, sample_class))[0]

img = Image.open(os.path.join(SOURCE_DIR, sample_class, sample_img))

plt.figure(figsize=(4,4))
plt.imshow(img)
plt.title(f"Contoh Citra Asli - Kelas {sample_class}")
plt.axis('off')
plt.show()

# %%
# ==============================================================================
# 3. DATA SPLITTING (80% TRAIN | 20% TEST)
# ==============================================================================
import os
import shutil
from sklearn.model_selection import train_test_split

print("\n===== 3. DATA SPLITTING =====")

TRAIN_DIR = '/kaggle/working/train'
TEST_DIR  = '/kaggle/working/test'

# Bersihkan folder lama agar konsisten
for d in [TRAIN_DIR, TEST_DIR]:
    if os.path.exists(d):
        shutil.rmtree(d)
    os.makedirs(d)

# Split data per kelas (stratified by folder)
for cls in class_names:
    cls_path = os.path.join(SOURCE_DIR, cls)
    files = os.listdir(cls_path)

    train_f, test_f = train_test_split(
        files,
        test_size=0.2,
        random_state=SEED,
        shuffle=True
    )

    os.makedirs(os.path.join(TRAIN_DIR, cls))
    os.makedirs(os.path.join(TEST_DIR, cls))

    for f in train_f:
        shutil.copy(
            os.path.join(cls_path, f),
            os.path.join(TRAIN_DIR, cls, f)
        )
    for f in test_f:
        shutil.copy(
            os.path.join(cls_path, f),
            os.path.join(TEST_DIR, cls, f)
        )

print("Data split completed successfully (80% train | 20% test).")
# Out:
# ===== 3. DATA SPLITTING =====
# Data split completed successfully (80% train | 20% test).

# %%
# ==============================================================================
# 4. DATA BALANCING ANALYSIS
# ==============================================================================
print("\n===== 4. DATA BALANCING =====")

counts = []
for cls in class_names:
    c = len(os.listdir(os.path.join(TRAIN_DIR, cls)))
    counts.append(c)
    print(f"{cls}: {c} images")

plt.figure(figsize=(10,5))
plt.bar(class_names, counts)
plt.xticks(rotation=45, ha='right')
plt.ylabel("Jumlah Citra")
plt.title("Distribusi Data Training per Kelas")
plt.tight_layout()
plt.show()

print("Dataset relatif seimbang → tidak dilakukan resampling.")

# %%
# ==============================================================================
# 5. DATA GENERATOR
# ==============================================================================
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications.efficientnet import preprocess_input

print("\n===== 5. DATA GENERATOR =====")

IMG_SIZE = (224, 224)
BATCH_SIZE = 32

train_datagen = ImageDataGenerator(
    preprocessing_function=preprocess_input,
    horizontal_flip=True
)

test_datagen = ImageDataGenerator(
    preprocessing_function=preprocess_input
)

train_ds = train_datagen.flow_from_directory(
    TRAIN_DIR,
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=True,
    seed=SEED
)

test_ds = test_datagen.flow_from_directory(
    TEST_DIR,
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=False
)

print(f"Training samples : {train_ds.samples}")
print(f"Testing samples  : {test_ds.samples}")
print(f"Classes detected: {len(train_ds.class_indices)}")

# %%
# ==============================================================================
# VISUALISASI
# SEBELUM vs SESUDAH PREPROCESSING
# ==============================================================================
from PIL import Image
import matplotlib.pyplot as plt
import numpy as np
import os

print("\n===== PERBANDINGAN CITRA SEBELUM & SESUDAH PREPROCESSING =====")

# ==========================
# 1. CITRA SEBELUM PREPROCESSING
# ==========================
sample_class = sorted(os.listdir(TRAIN_DIR))[0]
sample_img_name = os.listdir(os.path.join(TRAIN_DIR, sample_class))[0]
original_img_path = os.path.join(TRAIN_DIR, sample_class, sample_img_name)

original_img = Image.open(original_img_path)
original_array = np.array(original_img)

print("📌 INFORMASI CITRA SEBELUM PREPROCESSING")
print(f"- Resolusi         : {original_img.size} (width x height)")
print(f"- Rentang pixel    : {original_array.min()} – {original_array.max()}")
print(f"- Tipe data pixel  : {original_array.dtype}")

# ==========================
# 2. CITRA SETELAH PREPROCESSING
# ==========================
img_batch, _ = next(train_ds)
processed_img = img_batch[0]

print("\n📌 INFORMASI CITRA SETELAH PREPROCESSING")
print(f"- Resolusi         : {processed_img.shape[1]} x {processed_img.shape[0]}")
print(f"- Rentang pixel    : {processed_img.min():.2f} – {processed_img.max():.2f}")
print(f"- Tipe data pixel  : {processed_img.dtype}")

# Normalisasi hanya untuk VISUALISASI
processed_img_vis = (
    (processed_img - processed_img.min()) /
    (processed_img.max() - processed_img.min())
)

# ==========================
# 3. VISUALISASI PERBANDINGAN
# ==========================
plt.figure(figsize=(9,4))

# Sebelum
plt.subplot(1,2,1)
plt.imshow(original_img)
plt.title(
    f"Sebelum Preprocessing\n"
    f"Resolusi: {original_img.size}\n"
    f"Pixel: 0–255"
)
plt.axis('off')

# Sesudah
plt.subplot(1,2,2)
plt.imshow(processed_img_vis)
plt.title(
    f"Sesudah Preprocessing\n"
    f"Resolusi: {processed_img.shape[1]}×{processed_img.shape[0]}\n"
    f"Pixel: Ternormalisasi"
)
plt.axis('off')

plt.suptitle(
    "Perbandingan Citra Sebelum dan Sesudah Preprocessing",
    fontsize=12,
    fontweight='bold'
)

plt.tight_layout()
plt.show()

# %%
# ==============================================================================
# 6. MODELLING
# ==============================================================================
import tensorflow as tf
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, BatchNormalization
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.applications import EfficientNetB0

print("\n===== 6. MODELLING =====")

NUM_CLASSES = len(train_ds.class_indices)

base_model = EfficientNetB0(
    weights='imagenet',
    include_top=False,
    input_shape=(224, 224, 3)
)

# Freeze backbone (sesuai konfigurasi sebelumnya)
base_model.trainable = False

model = Sequential([
    base_model,
    GlobalAveragePooling2D(),
    BatchNormalization(),
    Dense(128, activation='relu'),
    BatchNormalization(),
    Dense(NUM_CLASSES, activation='softmax')
])

model.compile(
    optimizer=Adam(learning_rate=1e-4),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

model.summary()

# %%
# ==============================================================================
# 7. TRAINING
# ==============================================================================
import tensorflow as tf
from tensorflow.keras.callbacks import EarlyStopping

print("\n===== 7. TRAINING =====")

early_stop = EarlyStopping(
    monitor='val_loss',
    patience=6,
    restore_best_weights=True
)

history = model.fit(
    train_ds,
    validation_data=test_ds,
    epochs=15,
    callbacks=[early_stop],
    verbose=2
)

# %%
# ==============================================================================
# 8. MODEL EVALUATION (METRIC)
# ==============================================================================
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

print("\n===== 8. MODEL EVALUATION =====")

test_ds.reset()
pred_probs = model.predict(test_ds, verbose=0)
pred_labels = np.argmax(pred_probs, axis=1)
true_labels = test_ds.classes

acc = accuracy_score(true_labels, pred_labels)
prec = precision_score(true_labels, pred_labels, average='weighted')
rec = recall_score(true_labels, pred_labels, average='weighted')
f1 = f1_score(true_labels, pred_labels, average='weighted')

print(f"Accuracy  : {acc:.4f}")
print(f"Precision : {prec:.4f}")
print(f"Recall    : {rec:.4f}")
print(f"F1-score  : {f1:.4f}")

# %%
# ==============================================================================
# 8. MODEL EVALUATION (ACCURACY & LOSS CURVE)
# ==============================================================================
import matplotlib.pyplot as plt

plt.figure(figsize=(14, 5))

# -----------------------------
# Accuracy Curve
# -----------------------------
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Accuracy Curve')
plt.legend()
plt.grid(True)

# -----------------------------
# Loss Curve
# -----------------------------
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Loss Curve')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

# %%
# ==============================================================================
# VISUALISASI AKURASI AKHIR & CONFUSION MATRIX
# ==============================================================================
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

print("\n===== VISUALISASI AKURASI & CONFUSION MATRIX =====")

# ==========================
# 1. BAR CHART AKURASI AKHIR
# ==========================
plt.figure(figsize=(5,3))
plt.bar(['Accuracy'], [acc])
plt.ylim(0,1)
plt.title("Final Test Accuracy")

plt.text(
    0, acc + 0.02,
    f"{acc*100:.2f}%",
    ha='center',
    fontweight='bold'
)

plt.show()

# ==========================
# 2. CONFUSION MATRIX
# ==========================
idx_to_class = {v:k for k,v in test_ds.class_indices.items()}
labels = [idx_to_class[i] for i in range(NUM_CLASSES)]

cm = confusion_matrix(true_labels, pred_labels)

disp = ConfusionMatrixDisplay(
    confusion_matrix=cm,
    display_labels=labels
)

plt.figure(figsize=(10,8))
disp.plot(
    cmap=plt.cm.Blues,
    xticks_rotation=90,
    values_format='d'
)
plt.title("Confusion Matrix - Test Data")
plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

print("\n===== 9. SAMPLE PREDICTION CHECK (PER CLASS) =====")

# Mapping index → nama kelas
idx_to_class = {v: k for k, v in test_ds.class_indices.items()}
class_labels = [idx_to_class[i] for i in range(NUM_CLASSES)]

# --------------------------------------------------
# Ambil 1 sampel unik untuk setiap kelas
# --------------------------------------------------
samples = {}

test_ds.reset()
for imgs, lbls in test_ds:
    for img, lbl in zip(imgs, lbls):
        cls_idx = np.argmax(lbl)
        if cls_idx not in samples:
            samples[cls_idx] = img
        if len(samples) == NUM_CLASSES:
            break
    if len(samples) == NUM_CLASSES:
        break

# --------------------------------------------------
# Prediksi & Visualisasi
# --------------------------------------------------
plt.figure(figsize=(15, 15))

for i, cls_idx in enumerate(sorted(samples.keys())):
    img = samples[cls_idx]

    pred = model.predict(
        np.expand_dims(img, axis=0),
        verbose=0
    )[0]

    pred_idx = np.argmax(pred)
    confidence = np.max(pred) * 100

    true_label = class_labels[cls_idx]
    pred_label = class_labels[pred_idx]
    correct = "BENAR" if cls_idx == pred_idx else "SALAH"

    # Normalisasi hanya untuk visualisasi
    img_vis = (img - img.min()) / (img.max() - img.min())

    plt.subplot(3, 3, i + 1)
    plt.imshow(img_vis)
    plt.axis("off")
    plt.title(
        f"True      : {true_label}\n"
        f"Predict   : {pred_label}\n"
        f"Confidence: {confidence:.2f}%\n"
        f"Status    : {correct}",
        fontsize=11
    )

    # Output teks (untuk log / laporan)
    print(
        f"Class: {true_label} | "
        f"Predict: {pred_label} | "
        f"Confidence: {confidence:.2f}% | "
        f"Status: {correct}"
    )

plt.suptitle(
    "Sample Prediction Check – Satu Sampel per Kelas",
    fontsize=14,
    fontweight="bold"
)
plt.tight_layout()
plt.show()

# %%
# ==============================================================================
# 10. MODEL HEALTH CHECK (COMPREHENSIVE)
# ==============================================================================

import numpy as np

print("\n===== 10. MODEL HEALTH CHECK =====")

# ------------------------------------------------------------------
# 1. OVERFITTING / UNDERFITTING CHECK
# ------------------------------------------------------------------
train_acc = history.history['accuracy'][-1]
val_acc   = history.history['val_accuracy'][-1]
acc_gap   = abs(train_acc - val_acc)

print("\n[1] Overfitting Check")
print(f"Train Accuracy      : {train_acc:.4f}")
print(f"Validation Accuracy : {val_acc:.4f}")
print(f"Accuracy Gap        : {acc_gap:.4f}")

if acc_gap <= 0.05:
    fit_status = "SEHAT (Tidak overfitting)"
elif train_acc > val_acc:
    fit_status = "OVERFITTING"
else:
    fit_status = "UNDERFITTING"

print(f"Status              : {fit_status}")

# ------------------------------------------------------------------
# 2. DATA IMBALANCE CHECK
# ------------------------------------------------------------------
class_counts = np.bincount(train_ds.classes)
imbalance_ratio = class_counts.max() / class_counts.min()

print("\n[2] Data Imbalance Check")
print(f"Imbalance Ratio (max/min): {imbalance_ratio:.2f}")

if imbalance_ratio <= 2:
    data_status = "SEIMBANG"
else:
    data_status = "IMBALANCE"

print(f"Status               : {data_status}")

# ------------------------------------------------------------------
# 3. METRIC CONSISTENCY CHECK
# ------------------------------------------------------------------
metric_gap = max(acc, prec, rec, f1) - min(acc, prec, rec, f1)

print("\n[3] Metric Consistency Check")
print(f"Accuracy  : {acc:.4f}")
print(f"Precision : {prec:.4f}")
print(f"Recall    : {rec:.4f}")
print(f"F1-score  : {f1:.4f}")
print(f"Metric Gap: {metric_gap:.4f}")

if metric_gap <= 0.02:
    metric_status = "KONSISTEN"
else:
    metric_status = "TIDAK KONSISTEN"

print(f"Status    : {metric_status}")

# ------------------------------------------------------------------
# 4. CONFIDENCE PREDICTION CHECK
# ------------------------------------------------------------------
confidences = np.max(pred_probs, axis=1)

mean_conf = confidences.mean() * 100

print("\n[4] Confidence Prediction Check")
print(f"Mean Confidence : {mean_conf:.2f}%")

if mean_conf >= 70:
    conf_status = "PREDIKSI MEYAKINKAN"
else:
    conf_status = "PREDIKSI KURANG MEYAKINKAN"

print(f"Status          : {conf_status}")

# ------------------------------------------------------------------
# 5. FINAL HEALTH VERDICT
# ------------------------------------------------------------------
print("\n===== FINAL MODEL HEALTH VERDICT =====")

if (
    acc_gap <= 0.05 and
    imbalance_ratio <= 2 and
    metric_gap <= 0.02 and
    mean_conf >= 70
):
    print("KESIMPULAN : ✅ MODEL SEHAT, STABIL, DAN LAYAK DIGUNAKAN")
else:
    print("KESIMPULAN : ⚠️ MODEL MEMERLUKAN OPTIMASI LANJUTAN")

# %%
import json

# ==============================================================================
# 12. SAVE MODEL & LABEL MAPPING
# ==============================================================================
model.save("efficientnetb0_model.keras")

with open("class_indices.json", "w") as f:
    json.dump({v: k for k, v in train_ds.class_indices.items()}, f)

print("Model dan label mapping berhasil disimpan.")
